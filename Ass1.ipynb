# %% [markdown]
# <a href="https://colab.research.google.com/github/surajiiit/F-A-Course/blob/main/Ass1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **ASSIGNMENT-1**

# %% [markdown]
# **Importing Libraries**

# %%
# Importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import date
import warnings
import yfinance as yf

# Suppress warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Importing Options Data**

# %%
symbol = "^SPX"
dfo = yf.Ticker(symbol)

# Get current price using historical data (more reliable than info)
current_price = dfo.history(period='1d')['Close'].iloc[-1]

# Select the next recent expiration date
expiration_date = dfo.options[1]
option_chain = dfo.option_chain(expiration_date)

# Extract Calls and Puts Data
calls = option_chain.calls
puts = option_chain.puts

# %% [markdown]
# **Call Option Data**

# %%
calls
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0    SPXW241210C04800000 2024-12-06 17:17:54+00:00  4800.0    1285.97  1278.2
# 1    SPXW241210C04900000 2024-11-05 19:19:28+00:00  4900.0     898.00  1181.8
# 2    SPXW241210C05000000 2024-11-27 15:04:37+00:00  5000.0    1018.92  1078.2
# 3    SPXW241210C05050000 2024-11-27 15:04:37+00:00  5050.0     968.37  1028.2
# 4    SPXW241210C05150000 2024-12-06 16:06:05+00:00  5150.0     945.42   932.5
# ..                   ...                       ...     ...        ...     ...
# 105  SPXW241210C06400000 2024-12-04 19:59:21+00:00  6400.0       0.10     0.0
# 106  SPXW241210C06500000 2024-12-06 19:44:08+00:00  6500.0       0.05     0.0
# 107  SPXW241210C06600000 2024-12-04 16:09:50+00:00  6600.0       0.05     0.0
# 108  SPXW241210C06800000 2024-12-04 14:57:06+00:00  6800.0       0.05     0.0
# 109  SPXW241210C07000000 2024-11-25 18:21:36+00:00  7000.0       0.05     0.0
#
#          ask     change  percentChange  volume  openInterest  \
# 0    1294.90  157.80994      13.988258     1.0             3
# 1    1195.10    0.00000       0.000000     NaN             0
# 2    1095.00    0.00000       0.000000     8.0             8
# 3    1045.00    0.00000       0.000000     NaN             8
# 4     940.90   88.71997      10.356013     3.0             4
# ..       ...        ...            ...     ...           ...
# 105     0.05    0.00000       0.000000   100.0           100
# 106     0.05    0.00000       0.000000     2.0           263
# 107     0.05    0.00000       0.000000    67.0           109
# 108     0.05    0.00000       0.000000    10.0            11
# 109     0.05    0.00000       0.000000     5.0             6
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             1.279911        True      REGULAR      USD
# 1             1.191288        True      REGULAR      USD
# 2             1.091923        True      REGULAR      USD
# 3             1.044560        True      REGULAR      USD
# 4             0.724612        True      REGULAR      USD
# ..                 ...         ...          ...      ...
# 105           0.186532       False      REGULAR      USD
# 106           0.238289       False      REGULAR      USD
# 107           0.289070       False      REGULAR      USD
# 108           0.385748       False      REGULAR      USD
# 109           0.478521       False      REGULAR      USD
#
# [110 rows x 14 columns]

# %% [markdown]
# **Put Option Data**

# %%
puts
# Out:
#           contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0    SPXW241210P02400000 2024-11-20 17:38:53+00:00  2400.0       0.05    0.0
# 1    SPXW241210P02600000 2024-11-19 15:16:08+00:00  2600.0       0.12    0.0
# 2    SPXW241210P02800000 2024-11-26 20:24:26+00:00  2800.0       0.05    0.0
# 3    SPXW241210P03000000 2024-11-26 20:49:36+00:00  3000.0       0.05    0.0
# 4    SPXW241210P03200000 2024-11-25 21:05:02+00:00  3200.0       0.05    0.0
# ..                   ...                       ...     ...        ...    ...
# 125  SPXW241210P06100000 2024-12-06 21:14:17+00:00  6100.0      19.97   20.3
# 126  SPXW241210P06120000 2024-12-06 21:14:18+00:00  6120.0      34.01   31.3
# 127  SPXW241210P06125000 2024-12-06 20:58:56+00:00  6125.0      39.30   35.6
# 128  SPXW241210P06130000 2024-12-06 21:14:18+00:00  6130.0      42.56   40.0
# 129  SPXW241210P06200000 2024-12-06 20:01:06+00:00  6200.0     117.21  108.9
#
#         ask     change  percentChange  volume  openInterest  \
# 0      0.05   0.000000       0.000000     NaN            50
# 1      0.05   0.000000       0.000000     2.0             9
# 2      0.05   0.000000       0.000000     9.0            29
# 3      0.05   0.000000       0.000000    11.0            43
# 4      0.05   0.000000       0.000000    75.0            76
# ..      ...        ...            ...     ...           ...
# 125   20.80 -14.129999     -41.436950  1189.0           166
# 126   39.70 -15.790001     -31.706831    22.0            18
# 127   43.90 -10.330002     -20.814028     9.0             7
# 128   49.40  -8.539997     -16.712324     9.0            25
# 129  117.40   7.010002       6.361164     2.0            15
#
#      impliedVolatility  inTheMoney contractSize currency
# 0             2.781253       False      REGULAR      USD
# 1             2.546879       False      REGULAR      USD
# 2             2.328129       False      REGULAR      USD
# 3             2.132817       False      REGULAR      USD
# 4             1.945313       False      REGULAR      USD
# ..                 ...         ...          ...      ...
# 125           0.070101        True      REGULAR      USD
# 126           0.098146        True      REGULAR      USD
# 127           0.101327        True      REGULAR      USD
# 128           0.111329        True      REGULAR      USD
# 129           0.185753        True      REGULAR      USD
#
# [130 rows x 14 columns]

# %% [markdown]
# ## **Payoff Calculation**

# %% [markdown]
#  **Call option**
#
# payoff=max(-C, S - X - C)

# %% [markdown]
#  **Put option**
#
# payoff=max(-P, X - S - P)

# %% [markdown]
# where,
#
# P and C are premiums of calls and puts
#
# S is the stock price
#
# X is the strike price

# %%
def payoff(option_type, premium, S, X):
    """
    Calculate the payoff for an option position

    Parameters:
    option_type (str): 'C' for Call, 'P' for Put
    premium (float): Option premium
    S (float or array-like): Stock price or array of possible stock prices
    X (float): Strike price
    """
    if option_type == 'C':  # Call Option
        return max(0, S - X) - premium if isinstance(S, (int, float)) else [max(0, s - X) - premium for s in S]
    elif option_type == 'P':  # Put Option
        return max(0, X - S) - premium if isinstance(S, (int, float)) else [max(0, X - s) - premium for s in S]
    return "Option type not supported"

# %% [markdown]
# **Checking the output of payoff function**

# %%
payoff('C', 10, 120,100)  #answer displayed should be 10
# Out:
# 10

# %%
payoff('Z', 10, 120, 100)  #answer displayed should be option type not supported
# Out:
# 'Option type not supported'

# %%
payoff('P', 10, 120, 100)  #answer displayed should be -10
# Out:
# -10

# %% [markdown]
# **Plot for Call Option**

# %%
# Call Option Plot
X_call = calls['strike'].iloc[0]  # Using first strike price
premium_call = calls['lastPrice'].iloc[0]

# Create stock price range based on current price
price_range = 0.5  # 50% above and below current price
StockPrice = np.linspace(current_price * (1 - price_range),
                        current_price * (1 + price_range),
                        1000)

# Calculate payoff (vectorized)
Payoff_Call = payoff('C', premium_call, StockPrice, X_call)

# Plot the call option payoff
plt.figure(figsize=(10, 6))
plt.plot(StockPrice, Payoff_Call, label='Call Option Payoff')
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.7)
plt.axvline(x=X_call + premium_call, color='red', linestyle='--', label='Breakeven Point')
plt.xlabel('Stock Price')
plt.ylabel('Payoff ($)')
plt.title(f'Call Option Payoff at Expiry (Strike: ${X_call:,.2f})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Plot for Put Option**

# %%
# Put Option Plot
X_put = puts['strike'].iloc[-1]  # Using last strike price
premium_put = puts['lastPrice'].iloc[-1]

#YOUR CODE HERE FOR THE PLOT OF THE PUT OPTION
Payoff_Put = payoff('P', premium_put, StockPrice, X_put)

plt.plot(StockPrice, Payoff_Put, label='Put Option Payoff', color='blue')
plt.axhline(y=0, color='black', linestyle='--', linewidth=0.7)
plt.axvline(x=X_put - premium_put, color='red', linestyle='--', label='Breakeven Point')
plt.xlabel('Stock Price')
plt.ylabel('Payoff ($)')
plt.title(f'Put Option Payoff at Expiry (Strike: ${X_put:,.2f})')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Checking for ITM,OTM,ATM**

# %%
# Option Classification function
def classify_option(S, X):
    """
    Classify option as ITM, ATM, or OTM based on current stock price(S) and strike price(X)
    """
    if S > X:  # Call Option ITM condition
        return "In the Money (ITM)"
    elif S == X:
        return "At the Money (ATM)"
    else:  # Call Option OTM condition
        return "Out of the Money (OTM)"

# %%
# Example classification
classification_call = classify_option(current_price, X_call)
classification_put = classify_option(current_price, X_put)
print(f"\nCall Option Classification: {classification_call}")
print(f"Put Option Classification: {classification_put}")
# Out:
# Call Option Classification: In the Money (ITM)
# Put Option Classification: Out of the Money (OTM)

# %% [markdown]
# **Put Call Parity Validation**

# %%
# Put-Call Parity Validation
def validate_put_call_parity(S, X, premium_call, premium_put, r=0.05, T=1):
    """
    Validate Put-Call Parity relationship

    Parameters:
    S: Current stock price
    X: Strike price
    premium_call: Call option premium
    premium_put: Put option premium
    r: Risk-free interest rate (default 5%)
    T: Time to maturity in years (default 1 year)
    """
    left_hand_side = premium_call - premium_put
    right_hand_side = S - X * np.exp(-r * T)
    return np.isclose(left_hand_side, right_hand_side, rtol=1e-2)

# %% [markdown]
# **Check put-call parity**

# %%
# Check put-call parity
is_parity_valid = validate_put_call_parity(current_price, X_call, premium_call, premium_put)
print(f"\nDoes Put-Call Parity Hold? {is_parity_valid}")
# Out:
# Does Put-Call Parity Hold? False
